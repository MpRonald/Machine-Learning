# %% [markdown]
# # Data Visualization

# %%
# a instrução % matplotlib embutida foi usada para gerar 
# gráficos dentro do Jupyter Notebook

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import math

# %%
# utilizando um grafico de linhas
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt (i) for i in x_vals]
plt.plot(x_vals, y_vals)
plt.show()

# %% [markdown]
# No script 1, geramos 20 números equidistantes usando a função np.linspace (). Os números são armazenados na variável x_vals. Em seguida, iteramos por meio de cada valor na lista x_vals e obtemos a raiz quadrada de cada valor. A lista resultante é armazenada na variável y_vals. Para plotar um gráfico de linha por meio do módulo pyplot, você só precisa chamar o método plot() do módulo pyplot e, em seguida, passar os valores para os eixos x e y. É importante mencionar que plt é um apelido para pyplot no script 1 e você pode nomeá-lo como quiser.

# %%
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt (i) for i in x_vals]
fig = plt.figure(figsize=(8,6))
ax = plt.axes()
ax.plot (x_vals, y_vals)
plt.show()

# %% [markdown]
# Você pode melhorar a estética e a legibilidade de seus gráficos adicionando títulos, rótulos e legendas a eles. Vamos primeiro ver como adicionar títulos e rótulos a um gráfico.
#
# Para adicionar rótulos em eixos x e y, você precisa passar os valores de cadeia, respectivamente, aos xlabel e ylabel métodos da pyplot módulo.

# %%
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt (i) for i in x_vals]
plt.xlabel ( 'Valores X' )
plt.ylabel ( 'Valores Y' )
plt.title ( 'Square Roots' )
plt.plot (x_vals, y_vals)
plt.show()

# %% [markdown]
# Além de alterar os títulos e rótulos, você também pode especificar a cor do gráfico de linha. Para fazer isso, basta passar a notação abreviada do nome da cor para a função plot () , por exemplo, “r” para vermelho, “b” para azul e assim por diante.

# %%
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt (i) for i in x_vals]
plt.xlabel ( 'Valores X' )
plt.ylabel ( 'Valores Y' )
plt.title ( 'Square Roots' )
plt.plot (x_vals, y_vals, 'r')
plt.show()

# %% [markdown]
# Para adicionar uma legenda, você precisa fazer duas alterações. Primeiro, você tem que passar um valor de string para o atributo label da função plot () . Em seguida, você deve passar o valor para o atributo loc do método de legenda do módulo pyplot . No atributo loc , você deve passar a localização de sua legenda. O script a seguir plota uma legenda no canto superior central do gráfico.

# %%
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt (i) for i in x_vals]
plt.xlabel ( 'Valores X' )
plt.ylabel ( 'Valores Y' )
plt.title ( 'Square Roots' )
plt.plot (x_vals, y_vals, 'r', label='Raiz Quadrada')
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# Você também pode plotar vários gráficos de linha dentro de um gráfico. Tudo o que você precisa fazer é chamar o método plot () duas vezes com valores diferentes para os eixos x e y.

# %%
x_vals = np.linspace(0, 20, 20)
y_vals = [math.sqrt (i) for i in x_vals ** 2]
y2_vals = [math.sqrt (i) for i in x_vals ** 3]
plt.xlabel ( 'Valores X' )
plt.ylabel ( 'Valores Y' )
plt.title ( 'Square Roots' )
plt.plot (x_vals, y_vals, 'r' , label = 'Raiz quadrada' )
plt.plot (x_vals, y2_vals, 'b' , label = 'Cube' )
plt.legend (loc = 'upper center' )
plt.show()

# %% [markdown]
# Para estudar mais sobre o gráfico de linha Matplotlib, verifique a documentação oficial do Matplotlib para gráficos de linha:
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.plot.html
# <br>https://bit.ly/33BqsIR

# %% [markdown]
# # Plotagem usando arquivos CSV

# %% [markdown]
# Além de plotar o gráfico do Matplotlib usando dados na memória, você pode ler dados de fontes como arquivos CSV (Visualização separada por vírgula) e TSV (Visualização separada por tabulação).
#
# A melhor maneira de ler dados de um arquivo CSV é através do método read_csv() da biblioteca Pandas.
#
# Vamos ler o arquivo iris_data.csv. O arquivo está disponível na pasta Conjuntos de dados no repositório GitHub. Você pode baixar localmente. No método read_csv(), você simplesmente tem que passar o caminho do arquivo CSV.

# %%
import pandas as pd
data = pd.read_csv("iris.csv")

# %%
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal vs Petal Length")
plt.plot(data["sepal.length"], data["petal.length"])
plt.show()

# %% [markdown]
# # Gráficos de dispersão
# Um gráfico de dispersão é usado essencialmente para representar graficamente a relação entre duas colunas numéricas na forma de pontos dispersos. Normalmente, um gráfico espalhado é usado quando, para cada valor no eixo x, existem vários valores no eixo y. Para traçar um gráfico de dispersão, a função scatter() do módulo pyplot é usada. Você deve passar os valores para o eixo x e y. Além disso, você deve passar uma notação abreviada do valor da cor para o parâmetro c.

# %%
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.title("Sepal vs Petal Length")
plt.scatter(data["sepal.length"], data["petal.length"], c="b")
plt.show()

# %% [markdown]
# Para estudar mais sobre o gráfico de dispersão do Matplotlib, verifique a documentação oficial do Matplotlib para gráficos de dispersão
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.scatter.html
# <br>https://bit.ly/3a8Dtef

# %% [markdown]
# # Bar Plots
# O gráfico de barras é usado para representar graficamente a relação entre valores únicos em uma coluna categórica agrupada por uma função agregada, como soma, média, mediana, etc.

# %%
data_t = pd.read_csv("titanic.csv")

# %%
data_t.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived
# 0         1
# 1         0
# 2         0
# 3         0
# 4         1

# %%
plt.xlabel("Gender")
plt.ylabel("Ages")
plt.title("Gender vs Age")
plt.bar(data_t["Sex"],data_t["Age"])
# Out:
# <BarContainer object of 1313 artists>

# %% [markdown]
# Para estudar mais sobre os gráficos de barra do Matplotlib, verifique a documentação oficial do Matplotlib para gráficos de barra
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.bar.html
# <br>https://bit.ly/2PNKR5r

# %% [markdown]
# # Histogramas
# Os histogramas são usados basicamente para exibir a distribuição de dados para uma lista numérica de itens. O método hist() é usado para traçar um histograma. Você simplesmente tem que passar uma coleção de valores numéricos para o método hist(). Por exemplo, o seguinte histograma representa a distribuição de valores na coluna Idade do conjunto de dados do Titanic.

# %%
plt.title("Age Histogram")
plt.hist(data_t["Age"])
plt.show()

# %% [markdown]
# Para estudar mais sobre os histogramas do Matplotlib, verifique a documentação oficial do Matplotlib para histogramas
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.hist.html
# <br>https://bit.ly/30Elw3V

# %% [markdown]
# # Gráfico de Pizza
# Os gráficos de pizza, como o nome sugere, exibem a distribuição percentual dos valores em uma coluna categórica em termos de uma função agregada. Por exemplo, o script a seguir mostra a distribuição percentual de cargos em relação às categorias de cargos, ou seja, TI, Marketing, Ciência de Dados e Finanças. Para plotar um gráfico de pizza, o método pie () do módulo pyplot é usado. O primeiro parâmetro é a lista dos valores numéricos que você deseja converter e exibir em porcentagens. Em seguida, você deve passar uma lista de categorias para o parâmetro rótulos. O parâmetro explodir define a magnitude da divisão para cada categoria no gráfico de pizza. O parâmetro autopct define o formato no qual a porcentagem será exibida no gráfico de pizza.

# %%
labels = 'IT' , 'Marketing' , 'Data Science' , 'Finance'
values = [500, 156, 300, 510]
explode = (0.05, 0.05, 0.05, 0.05)
plt.pie (values, explode = explode, labels = labels,\
         autopct = '% 1.1f %%' , shadow = True)
plt.show()

# %% [markdown]
# # Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = [10,8]

# %%
tips_data = sns.load_dataset('tips')

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# O script acima importa as bibliotecas Matplotlib e Seaborn. Em seguida, o tamanho do gráfico padrão é aumentado para 10 x 8. Depois disso, o método load_dataset() do módulo Seaborn é usado para carregar o conjunto de dados de 'tips' . Finalmente, os primeiros cinco registros do conjunto de dados de 'tips' foram exibidos no console.

# %%
# Dist Plot
plt.rcParams [ 'figure.figsize' ] = [10,8]
sns.distplot (tips_data [ 'total_bill' ])
# Out:
# /home/ronald/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# Leituras adicionais - Parcelas de distribuição Seaborn
# Para estudar mais sobre os lotes de distribuição da Seaborn, verifique a documentação oficial da Seaborn para lotes de distribuição
# https://seaborn.pydata.org/generated/seaborn.distplot.html<br>
# https://bit.ly/3abHC10<br>
# Tente traçar gráficos de distribuição com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# #### Joint Plot
# O gráfico 'join' é usado para representar graficamente a distribuição do histograma de duas colunas, uma no eixo x e outra no eixo y. Um gráfico de dispersão é desenhado por padrão para os pontos nas duas colunas. Para traçar um gráfico comum, você precisa chamar a função jointplot(). Os seguintes parcelas de script uma trama conjunta para total_bill e ponta colunas do 'tips' dataset.

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips_data)

# %% [markdown]
# O gráfico de dispersão pode ser substituído por uma linha de regressão em um gráfico comum. Para fazer isso, você precisa passar reg como o valor para o parâmetro de tipo da função jointplot().

# %%
sns.jointplot(x = 'size', y = 'total_bill',
              data = tips_data, kind = 'reg' )

# %% [markdown]
# Leituras Adicionais - Parcelas Conjuntas Seaborn
# Para estudar mais sobre parcelas conjuntas da Seaborn, verifique a documentação oficial da Seaborn para parcelas conjuntas
# https://seaborn.pydata.org/generated/seaborn.jointplot.html<br>
# https://bit.ly/31DHFyO<br>
# Tente traçar parcelas conjuntas com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# O gráfico de pares é usado para traçar um gráfico comum para todas as combinações de colunas numéricas e booleanas em um conjunto de dados. Para traçar um gráfico de pares, você precisa chamar a função pairplot() e passá-la para seu conjunto de dados.

# %%
sns.pairplot(data = tips_data)

# %% [markdown]
# Leituras adicionais - Gráfico de pares marinhos
# Para estudar mais sobre os gráficos de pares Seaborn, verifique a documentação oficial da Seaborn para gráficos de pares
# https://seaborn.pydata.org/generated/seaborn.pairplot.html<br>
# https://bit.ly/3a7PdgK <br>
# Tente representar plotagens em pares com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %%
# barplot
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams ['figure.figsize'] = [8,6]
sns.set_style('darkgrid')
titanic_data = sns.load_dataset('titanic')
titanic_data.head ()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# salvando arquivo em csv
# titanic_data.to_csv('titanic.csv')

# %%
# A seguir, chamaremos a função barplot () da biblioteca Seaborn
sns.barplot(x = 'pclass' ,y = 'age', data = titanic_data)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# O resultado mostra que a idade média dos passageiros que viajam na primeira classe está entre 35 e 40 anos. A idade média dos passageiros que viajam na segunda classe é em torno de 30, enquanto os passageiros que viajam na 3ª classe têm uma idade média de 25 .
#
# Leituras adicionais - Seaborn Bar Plot<br>
# Para estudar mais sobre plotagens de barra da Seaborn, verifique a documentação oficial da Seaborn para plotagem de barra <br>
# https://seaborn.pydata.org/generated/seaborn.barplot.html<br>
# https://bit.ly/2Dw5DDO<br>
# Tente plotar plotagens de barra com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# # Count Plot
#
# O gráfico de contagem representa um gráfico como um gráfico de barra. No entanto, ao contrário de um gráfico de barra que plota valores médios, o gráfico de contagem simplesmente exibe as contagens das ocorrências de registros para cada valor exclusivo em uma coluna categórica.<br>
# A função countplot() é usada para traçar um gráfico de contagem com Seaborn. O script a seguir plota um gráfico de contagem para a coluna pclass do conjunto de dados do Titanic .

# %%
sns.countplot (x = 'pclass', data = titanic_data)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %% [markdown]
# Para estudar mais sobre plotagens de contagem Seaborn, verifique a documentação oficial da Seaborn para plotagens de contagem<br>
# https://seaborn.pydata.org/generated/seaborn.countplot.html<br>
# https://bit.ly/3ilzH3N<br>
# Tente fazer plotagens de contagem com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# ### Box Plot
# O gráfico de caixa é usado para plotar as informações do quartil para os dados em uma coluna numérica. Para plotar um gráfico de caixa, o método boxplot() é usado. Para traçar um gráfico de caixa horizontal, o nome da coluna do conjunto de dados é passado para o eixo x. O script a seguir plota um gráfico de caixa para a coluna de tarifa do conjunto de dados do Titanic .

# %%
sns.boxplot(x = titanic_data.fare)
# Out:
# <AxesSubplot:xlabel='fare'>

# %% [markdown]
# Para estudar mais sobre os boxplots da Seaborn, verifique a documentação oficial da Seaborn para boxplots<br>
# https://seaborn.pydata.org/generated/seaborn.boxplot.html<br>
# https://bit.ly/3kpH4Jw<br>
# Tente representar plotagens de caixa com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# Os gráficos de violino são semelhantes aos gráficos de caixa. No entanto, ao contrário dos gráficos de caixa que representam informações de quartil, os gráficos de violino representam a distribuição geral dos valores nas colunas numéricas. O seguinte roteiro traça duas tramas de violino para os passageiros que viajam sozinhos e para os passageiros que viajam com outro passageiro. A função violinplot() é usada para traçar um enredo de enxame com Seaborn.

# %%
sns.violinplot(x = 'alone', y = 'age', data = titanic_data)
# Out:
# <AxesSubplot:xlabel='alone', ylabel='age'>

# %% [markdown]
# O resultado mostra que, entre os passageiros que viajam sozinhos, são muito poucos os passageiros com menos de 15 anos, como mostra o gráfico do violino laranja à direita. Esse comportamento é compreensível, pois as crianças normalmente estão acompanhadas por alguém. Isso pode ser verificado ainda mais olhando para o gráfico do violino azul à esquerda que corresponde aos passageiros acompanhados por outros passageiros.

# %% [markdown]
# Leituras adicionais - Trama do violino do mar
# Para estudar mais sobre tramas de violino Seaborn, verifique a documentação oficial da Seaborn para tramas de violino<br>
# https://seaborn.pydata.org/generated/seaborn.violinplot.html<br>
# https://bit.ly/30F0qT9<br>
# Tente traçar tramas de violino com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# # Visualização de dados via Pandas
# Na seção anterior, você viu como plotar diferentes tipos de plotagens com a biblioteca Seaborn. Neste capítulo, você verá como a biblioteca Pandas pode ser usada para plotar diferentes tipos de visualizações. Na verdade, a biblioteca Pandas é provavelmente a biblioteca mais fácil para plotagem de dados, como você verá neste capítulo.

# %%
import pandas as pd

# %%
titanic_data = pd.read_csv('titanic.csv')

# %%
titanic_data.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %% [markdown]
# # Histogramas com Pandas

# %%
import matplotlib.pyplot as plt
titanic_data.age.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Leituras adicionais - Histograma Pandas
# Para estudar mais sobre o histograma do Pandas, verifique a documentação oficial do Pandas para o histograma<br>
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html<br>
# https://bit.ly/30F0qT9<br>
# Tente executar o método do histograma com um conjunto de atributos diferente, conforme mencionado na documentação oficial.

# %%
# Line Plots
flights_data = sns.load_dataset('flights')

# %%
flights_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flight_data.plot.line(y = 'passengers', figsize = (8,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Leituras adicionais - gráficos de linhas de pandas
# Para estudar mais sobre os gráficos de linha do Pandas, verifique a documentação oficial do Pandas para lotes de linha
#
# https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.plot.line.html
#
# https://bit.ly/30F0qT9
#
# Tente executar o método line () com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# # Gráficos de dispersão de pandas
# A função scatter() é usada para traçar gráficos de dispersão com Pandas. O script a seguir plota um gráfico de dispersão contendo o ano no eixo xe o número de passageiros no eixo y.

# %%
flights_data.plot.scatter(x='year', y='passengers', figsize=(6,4))
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %% [markdown]
# Leituras adicionais - gráficos de dispersão de pandas
# Para estudar mais sobre os gráficos de dispersão do Pandas, verifique a documentação oficial do Pandas para gráficos de dispersão
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.scatter.html
#
# https://bit.ly/2DxSg6b
#
# Tente executar o método scatter () com um conjunto diferente de atributos, conforme mencionado na documentação oficial.

# %% [markdown]
# # Pandas Bar Plots
# Para plotar plotagens de barra com Pandas, você precisa de uma lista de categorias e uma lista de valores. A lista de categorias e a lista de valores devem ter o mesmo comprimento. Vamos traçar um gráfico de barras que mostra a idade média dos passageiros do sexo masculino e feminino.

# %%
titanic_data.head()
# Out:
#    Unnamed: 0  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0           0         0       3    male  22.0      1      0   7.2500        S
# 1           1         1       1  female  38.0      1      0  71.2833        C
# 2           2         1       3  female  26.0      0      0   7.9250        S
# 3           3         1       1  female  35.0      1      0  53.1000        S
# 4           4         0       3    male  35.0      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False
# 4  Third    man        True  NaN  Southampton    no   True

# %%
sex_mean = titanic_data.groupby('sex')['age'].mean ()

# %%
print(sex_mean)
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
print(type(sex_mean.tolist()))
# Out:
# <class 'list'>

# %% [markdown]
# Em seguida, precisamos criar um novo dataframe Pandas com duas colunas: Gênero e Idade, e então podemos simplesmente usar o método bar() para traçar um gráfico de barra que exibe as idades médias dos passageiros do sexo masculino e feminino no navio do Titanic.

# %%
df = pd.DataFrame({'Gender':['Female', 'Male'], 'Age':sex_mean.tolist()})
ax = df.plot.bar(x='Gender', y='Age', figsize=(8,6))

# %% [markdown]
# To study more about Pandas bar plots, please check Pandas’ official documentation for bar plots
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
#
# https://bit.ly/31uCe5a
#
# Try to execute bar plot methods with a different set of attributes, as mentioned in the official documentation.

# %% [markdown]
# # Pandas Box Plots
# Para plotar plotagens de caixa por meio da biblioteca Pandas, você precisa chamar a função box() . O script a seguir faz plotagens de caixa para todas as colunas numéricas no conjunto de dados do Titanic.
